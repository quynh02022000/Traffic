# %% [markdown]
# <a href="https://colab.research.google.com/github/quynh02022000/Traffic/blob/main/code/nodes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_nodes = pd.read_csv('https://raw.githubusercontent.com/quynh02022000/Traffic/main/data/nodes.csv')
df_nodes.head(10)
# Out:
#          _id        long        lat
# 0  366367223  106.629056  10.804243
# 1  366367233  106.709701  10.771110
# 2  366367242  106.737189  10.709337
# 3  366367274  106.760081  10.854489
# 4  366367285  106.721163  10.804994
# 5  366367319  106.618552  10.790438
# 6  366367322  106.657136  10.799155
# 7  366367330  106.564926  10.846947
# 8  366367338  106.632575  10.723753
# 9  366367340  106.714288  10.803099

# %%
frame = pd.DataFrame(df_nodes)
frame
# Out:
#                _id        long        lat
# 0        366367223  106.629056  10.804243
# 1        366367233  106.709701  10.771110
# 2        366367242  106.737189  10.709337
# 3        366367274  106.760081  10.854489
# 4        366367285  106.721163  10.804994
# ...            ...         ...        ...
# 577962  6202895387  106.647884  10.886330
# 577963  6202895388  106.649075  10.876678
# 577964  6203301188  106.700737  10.774919
# 577965  6203333885  106.699275  10.768892
# 577966  6205235785  106.691436  10.764490
#
# [577967 rows x 3 columns]

# %%
frame2 = pd.DataFrame (df_nodes, columns = ['_id', 'lat'])
frame2
# Out:
#                _id        lat
# 0        366367223  10.804243
# 1        366367233  10.771110
# 2        366367242  10.709337
# 3        366367274  10.854489
# 4        366367285  10.804994
# ...            ...        ...
# 577962  6202895387  10.886330
# 577963  6202895388  10.876678
# 577964  6203301188  10.774919
# 577965  6203333885  10.768892
# 577966  6205235785  10.764490
#
# [577967 rows x 2 columns]

# %%
frame3 = pd.DataFrame (df_nodes, columns = ['_id', 'long'])
frame3
# Out:
#                _id        long
# 0        366367223  106.629056
# 1        366367233  106.709701
# 2        366367242  106.737189
# 3        366367274  106.760081
# 4        366367285  106.721163
# ...            ...         ...
# 577962  6202895387  106.647884
# 577963  6202895388  106.649075
# 577964  6203301188  106.700737
# 577965  6203333885  106.699275
# 577966  6205235785  106.691436
#
# [577967 rows x 2 columns]
